# %%
R = 300
pi = math.pi
i = 0
while i < 2:
    j = 0
    z = R * math.cos(pi * i)
    while j < 2:
        x = R * math.sin(pi * i) * math.cos(pi * j)
        y = R * math.sin(pi * i) * math.sin(pi * j)
        point3D = {'x': 0, 'y': 0, 'z': 0}
        point3D['x'] = x
        point3D['y'] = y
        point3D['z'] = z
        listpoint.append(point3D)
        j = j + 0.1
    i = i + 0.1
print(listpoint)
# Out:
# 050983124842}, {'x': 230.82626528814427, 'y': -167.7050983124839, 'z': -92.7050983124842}, {'x': 271.3525491562423, 'y': -88.16778784387056, 'z': -92.7050983124842}, {'x': 242.70509831248424, 'y': 0.0, 'z': -176.3355756877419}, {'x': 230.82626528814401, 'y': 75.0, 'z': -176.3355756877419}, {'x': 196.35254915624213, 'y': 142.65847744427305, 'z': -176.3355756877419}, {'x': 142.65847744427302, 'y': 196.35254915624213, 'z': -176.3355756877419}, {'x': 75.00000000000001, 'y': 230.82626528814401, 'z': -176.3355756877419}, {'x': 1.4861401089256373e-14, 'y': 242.70509831248424, 'z': -176.3355756877419}, {'x': -74.99999999999999, 'y': 230.82626528814404, 'z': -176.3355756877419}, {'x': -142.65847744427302, 'y': 196.35254915624213, 'z': -176.3355756877419}, {'x': -196.3525491562421, 'y': 142.65847744427307, 'z': -176.3355756877419}, {'x': -230.826265288144, 'y': 75.00000000000013, 'z': -176.3355756877419}, {'x': -242.70509831248424, 'y': 1.3750551751468565e-13, 'z': -176.3355756877419}, {'x': -
# ...
